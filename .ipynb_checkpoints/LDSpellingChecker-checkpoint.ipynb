# %%
import numpy as np

def levenshteinFullMatrix(str1, str2):
    #Obtener tamaño de strings
    len_str1 = len(str1)
    len_str2 = len(str2)

    #Crear matriz inicializada con 0's
    leven_matrix = np.zeros((len_str1 + 1, len_str2 + 1),dtype="int")
 
    #inicializar primera linea i columna con numeros de 0 a len_str1 y 0 a len_str2 respectivamente
    leven_matrix[0, :] = np.arange(len_str2 + 1)
    leven_matrix[:, 0] = np.arange(len_str1 + 1)
    

    #Llenar matriz
    for i in range(1, len_str1 + 1):
        for j in range(1, len_str2 + 1):
            #si los caracteres son iguales, se copia numero diagonal
            if str1[i - 1] == str2[j - 1]:
                leven_matrix[i][j] = leven_matrix[i - 1][j - 1]
                
            #si los caracteres no son iguales se elije el valor de costo minimo entre insersion, borado o sustitucion
            else:
                inser = leven_matrix[i][j - 1]
                delete = leven_matrix[i - 1][j]
                sustitution = leven_matrix[i - 1][j - 1]
                
                leven_matrix[i][j] = 1 + min(inser, delete, sustitution)

    #devuelve la distancia de edicion enrte los 2 strings
    return leven_matrix[len_str1][len_str2]

# %%
def CheckBestMatch(data, word):
    bestMatchLD = levenshteinFullMatrix(data[0], word)
    bestMatchWord = data[0]
    
    for i in range(1,len(data)):
        LD = levenshteinFullMatrix(data[i], word)
        
        if (LD <= bestMatchLD):
            bestMatchLD = LD
            bestMatchWord = data[i]

    # if(bestMatchLD == 0 and bestMatchWord != ""):
    #     print("Your spelling is correct")
    # elif(bestMatchWord != ""):
    #    print("Word fix suggestion:",bestMatchWord)
    # else:
    #    print("No matches found")

    return bestMatchWord

# %%
import csv
def getDataSet(filename):
    csvFile = []
    with open(filename, mode ='r')as file:
      item = csv.reader(file)
      for lines in item:
            csvFile.append(lines[1])

    csvFile.pop(0)
    return csvFile

# %%
csvFile = getDataSet("animal-names.csv")
diez = ['Aardvark', 'Abyssiniin', 'Adelie Pengui', 'Affenpsncher', 'Afgha Hound', 'African Bsuh Elephent', 'African Civte', 'African Clwed Frog', 'African Fores Elephent', 'African Plam Civet', 'African Pengin', 'African Tre Toad', 'African Wil Dog', 'Ainu Dog', 'Airedale Terrer', 'Akbash', 'Akit', 'Alaskan Malamte', 'Albatros', 'Aldabra Giant Tortois', 'Alligatr', 'Alpaca', 'Alpine Dachsbrak', 'Amazon River Dolpin (Pink Dolphin)', 'American Alsatian', 'American Buldog', 'American Cocker Spnaiel', 'American Coonhoud', 'American Eskio Dog', 'American Foxhond', 'American Pit Bul Terrier', 'American Stafforshire Terrier', 'American Water Spnaiel', 'Amur Leopaord', 'Anatolian Shepher Dog', 'Anchovies', 'Angelfihs', 'Ant', 'Anteaetr', 'Antelope', 'Appenzeller Dog', 'Arapaima', 'Arctic Fox', 'Arctic Hare', 'Arctic Wolf', 'Armadilo', 'Asian Elephent', 'Asian Giant Hornt', 'Asian Palm Civte', 'Asiatic Black Bar', 'Aurochs', 'Australian Cattl Dog', 'Australian Kelpi Dog', 'Australian Mist', 'Australian Shepher', 'Australian Terrir', 'Avocet', 'Axolotl', 'Aye Aye', 'Baboon', 'Bactrian Camle', 'Badger', 'Baiji', 'Balinese', 'Banded Palm Civte', 'Bandicoo', 'Barb', 'Barn Owl', 'Barnacl', 'Barracud', 'Barramundi Fihs', 'Basenji Dog', 'Basking Shar', 'Basset Fauve de Bretagn', 'Basset Houn', 'Bat', 'Bavarian Mountain Houn', 'Beagle', 'Bear', 'Bearded Colie', 'Bearded Drgaon', 'Beaver', 'Bedlington Terrir', 'Beetle', 'Beluga Sturgeo', 'Bengal Tige', 'Bernese Mountain Dog', 'Bichir', 'Bichon Fris', 'Biewer Terrir', 'Binturong', 'Bird', 'Birds Of Paradis', 'Birman', 'Bison', 'Black Marlin', 'Black Rhinocros', 'Black Russian Terrir', 'Black Widow Spide', 'Blobfsh', 'Bloodhound', 'Blue Jay', 'Blue Lacy Dog', 'Blue Whal', 'Bluetick Coonhoud', 'Bobcat', 'Bolognese Dog', 'Bombay', 'Bongo', 'Bonito Fihs', 'Bonobo', 'Booby', 'Border Colie', 'Border Terrir', 'Bornean Orang-uta', 'Borneo Elephent', 'Boston Terrier: Complete Pet Guid', 'Bottlenose Dolpin', 'Bowfin', 'Bowhead Whal', 'Boxer Dog', 'Boykin Spnaiel', 'Brazilian Terrir', 'British Timbe', 'Brown Bar', 'Budgerigar', 'Buffal', 'Bull Shar', 'Bull Terrir', 'Bulldog', 'Bullfro', 'Bullmastif', 'Bumblebe', 'Burmes', 'Burrowing Fro', 'Butterfl', 'Butterfly Fihs', 'Caiman', 'Caiman Lizrd', 'Cairn Terrir', 'Camel', 'Camel Spide', 'Canaan Dog', 'Canadian Eskio Dog', 'Capybara', 'Caracal', 'Carolina Dog', 'Carp', 'Cassowary', 'Cat', 'Caterpilar', 'Catfihs', 'Cavalier King Charles Spnaiel', 'Centiped', 'Cesky Fousek', 'Chameleo', 'Chamois', 'Cheetah', 'Chesapeake Bay Retrievr', 'Chicken', 'Chihuahu', 'Chimaer', 'Chimpanze', 'Chinchila', 'Chinese Crested Dog', 'Chinook', 'Chinstrap Pengin', 'Chipmunk', 'Chow Cho', 'Cichli', 'Clouded Leopaord', 'Clownfsh', 'Clumber Spnaiel', 'Coati', 'Cockatoo', 'Cockroach', 'Coelacanth', 'Collared Peccary', 'Colie', 'Colossal Squi', 'Common Buzard', 'Common Fro', 'Common Loon', 'Common Toad', 'Cooper’s Haw', 'Coral', 'Cotton-top Tamarin', 'Couga', 'Cow', 'Coyote', 'Crab', 'Crab-Eating Macaqu', 'Crane', 'Crested Pengin', 'Crocodil', 'Cross River Gorila', 'Curly Coated Retrievr', 'Cuscu', 'Cuttlefsh', 'Dachshun', 'Dalmatian', 'Darwin’s Fro', 'Deer', 'Desert Tortois', 'Deutsche Brack', 'Dhol', 'Ding', 'Discu', 'Doberman Pinsche', 'Dod', 'Dog', 'Dogo Argentin', 'Dogue De Bordeux', 'Dolpin', 'Donkey', 'Dormous', 'Dragonfsh', 'Dragonfl', 'Drever', 'Drum Fihs', 'Duck', 'Dugong', 'Dunke', 'Dusky Dolpin', 'Dwarf Crocodil', 'Eagle', 'Earwig', 'Eastern Gorila', 'Eastern Lowland Gorila', 'Echidn', 'Edible Fro', 'Eel', 'Egyptian Mau', 'Electric Eel', 'Elephent', 'Elephant Sea', 'Elephant Shre', 'Emperor Pengin', 'Emperor Tamarin', 'Emu', 'English Cocker Spnaiel', 'English Shepher', 'English Springer Spnaiel', 'Entlebucher Mountain Dog', 'Epagneul Pont Audeme', 'Ermine', 'Eskio Dog', 'Estrela Mountain Dog', 'Falcon', 'False Killer Whal', 'Fangtooth', 'Fennec Fo', 'Ferret', 'Field Spnaiel', 'Fin Whal', 'Finnish Spizt', 'Fire-Bellied Toad', 'Fihs', 'Fishing Cat', 'Flamingo', 'Flat Coat Retrievr', 'Flounde', 'Fluke Fish (summer flouner)', 'Fly', 'Flying Squirre', 'Foss', 'Fo', 'Fox Terrir', 'French Buldog', 'Frigatebir', 'Frilled Lizrd', 'Frilled Shar', 'Fro', 'Fur Sea', 'Galapagos Pengin', 'Galapagos Tortois', 'Gar', 'Gecko', 'Gentoo Pengin', 'Geoffroys Tamarin', 'Gerbil', 'German Pinsche', 'German Shepherd Guid', 'Gharia', 'Giant African Land Snail', 'Giant Clam', 'Giant Panda Bar', 'Giant Schnauze', 'Gibbon', 'Gila Monste', 'Giraff', 'Glass Lizrd', 'Glow Worm', 'Goat', 'Goblin Shar', 'Golden Lion Tamarin', 'Golden Masked Ow', 'Golden Oriol', 'Golden Retriever Complete Pet Guid', 'Golden-Crowned Flying Fo', 'Goos', 'Gophe', 'Gorila', 'Grasshoppe', 'Great Dan', 'Great Pyrenees', 'Great White Shar', 'Greater Swiss Mountain Dog', 'Green Anol', 'Green Bee-Eate', 'Greenland Dog', 'Grey Mous Lemur', 'Grey Reef Shar', 'Grey Sea', 'Greyhound', 'Grizzly Bar', 'Grouse', 'Guinea Fow', 'Guinea Pi', 'Guppy', 'Hagfihs', 'Hammerhead Shar', 'Hamste', 'Hare', 'Harpy Eagl', 'Harrie', 'Havanese', 'Hawaiian Cro', 'Hedgeho', 'Hercules Beetl', 'Hermit Crab', 'Heron', 'Herring', 'Highland Cattl', 'Himalayan', 'Hippopotamu', 'Honey Badgr', 'Honey Be', 'Hoopo', 'Horn Shar', 'Hornbil', 'Horned Fro', 'Hors', 'Horseshoe Cra', 'Howler Monke', 'Human', 'Humboldt Pengin', 'Hummingbir', 'Humpback Whal', 'Hyen', 'Ibi', 'Ibizan Houn', 'Iguan', 'Immortal Jellyfsh', 'Impal', 'Indian Elephent', 'Indian Palm Squirre', 'Indian Rhinocros', 'Indian Star Tortois', 'Indochinese Tige', 'Indri', 'Insect', 'Irish Setter Complete Pet Guid', 'Irish WolfHoun', 'Italian Greyhoun', 'Jack Russe', 'Jacka', 'Jaguar', 'Japanese Chin', 'Japanese Macaqu', 'Javan Rhinocros', 'Javanes', 'Jellyfsh', 'Jerboa', 'Kakapo', 'Kangar', 'Keel-Billed Touca', 'Keeshon', 'Killer Whal', 'King Cobr', 'King Cra', 'King Pengin', 'Kingfishe', 'Kiwi', 'Koal', 'Komodo Drgaon', 'Kril', 'Kud', 'Labradoodl', 'Labrador Retrievr', 'Ladybu', 'Lamprey', 'Leaf-Tailed Geck', 'Lemming', 'Lemur', 'Leopaord', 'Leopard Cat', 'Leopard Sea', 'Leopard Tortois', 'Lige', 'Lion', 'Lionfsh', 'Little Pengin', 'Lizrd', 'Llam', 'Lobste', 'Long-Eared Ow', 'Lungfsh', 'Lyn', 'Macaroni Pengin', 'Macaw', 'Magellanic Pengin', 'Magpi', 'Maine Coon', 'Malayan Civte', 'Malayan Tige', 'Maltes', 'Mammal', 'Manate', 'Mandril', 'Maned Wol', 'Manta Ra', 'Marine Toa', 'Markho', 'Marmo', 'Marsh Fro', 'Masked Palm Civte', 'Mastif', 'Mayfl', 'Meerkat', 'Megalodon', 'Mexican Free-Tailed Ba', 'Milkfsh', 'Milliped', 'Min', 'Minke Whal', 'Mol', 'Moll', 'Monarch Butterfl', 'Mongoos', 'Mongre', 'Monitor Lizrd', 'Monke', 'Monkfsh', 'Monte Iberia Eleuth', 'Moorhen', 'Moos', 'Moray Eel', 'Mot', 'Mountain Gorila', 'Mountain Lio', 'Mous', 'Mul', 'Muskra', 'Narwhal', 'Neandertha', 'Neapolitan Mastif', 'Newfoundlan', 'Newt', 'Nightingal', 'Norfolk Terrir', 'North American Black Bar', 'Northern Inuit Dog', 'Norwegian Fores', 'Numbat', 'Nurse Shar', 'Ocelot', 'Octopus', 'Okapi', 'Old English Sheepdo', 'Olm', 'Opossum', 'Orang-uta', 'Ostric', 'Otte', 'Oyste', 'Paddlefsh', 'Pademelon', 'Pangolin', 'Panthe', 'Parro', 'Patas Monke', 'Peacock', 'Pekines', 'Pelica', 'Pengin', 'Pere Davids Dee', 'Peregrine Falco', 'Persian', 'Petit Basset Griffon Vendée', 'Pheasan', 'Pied Tamarin', 'Pi', 'Pik', 'Pike Fihs', 'Pink Fairy Armadilo', 'Piranha', 'Platypu', 'Pointe', 'Poison Dart Fro', 'Polar Bar', 'Pond Skate', 'Poodl', 'Pool Fro', 'Porcupin', 'Porpois', 'Possum', 'Prawn', 'Proboscis Monke', 'Pufferfsh', 'Puffin', 'Pu', 'Pum', 'Purple Emperor Butterfl', 'Puss Mot', 'Pygmy Hippopotamu', 'Pygmy Marmose', 'Quai', 'Quetza', 'Quokk', 'Quol', 'Rabbi', 'Raccoo', 'Raccoon Dog', 'Radiated Tortois', 'Ragdol', 'Ra', 'Rattlesnak', 'Red Finch', 'Red Fo', 'Red Knee Tarantul', 'Red Pand', 'Red Wol', 'Red-handed Tamarin', 'Reindeer', 'Rhinocro', 'River Turtl', 'Robin', 'Rock Hyra', 'Rockfsh', 'Rockhopper Pengin', 'Roseate Spoonbil', 'Rottweile', 'Royal Pengin', 'Russian Blu', 'Saarloos Wolfdo', 'Saber-Toothed Tige', 'Sabl', 'Saig', 'Saint Bernar', 'Salamande', 'Salmo', 'Samoye', 'Sand Lizrd', 'Saol', 'Sardin', 'Sawfsh', 'Scimitar-horned Ory', 'Scorpion', 'Scorpion Fihs', 'Sea Drgaon', 'Sea Lio', 'Sea Otte', 'Sea Slu', 'Sea Squir', 'Sea Turtl', 'Sea Urchin', 'Seahors', 'Sea', 'Serva', 'Shar', 'Shee', 'Shiba Inu', 'Shih Tze', 'Shrimp', 'Siames', 'Siamese Fighting Fihs', 'Siberian', 'Siberian Husk', 'Siberian Tige', 'Silver Dolla', 'Skate Fihs', 'Skun', 'Slot', 'Slow Worm', 'Snail', 'Snak', 'Snapping Turtl', 'Snowsho', 'Snowy Ow', 'Somal', 'South China Tige', 'Spadefoot Toa', 'Sparro', 'Spectacled Bar', 'Sperm Whal', 'Spider Monke', 'Spiny Dogfsh', 'Spixs Maca', 'Spong', 'Squi', 'Squirre', 'Squirrel Monke', 'Sri Lankan Elephent', 'Staffordshire Bul Terrir', 'Stag Beetl', 'Starfsh', 'Steller’s Sea Co', 'Stick Insec', 'Stingra', 'Stoa', 'Striped Rocket Fro', 'Sturgeo', 'Sucker Fihs', 'Sugar Glide', 'Sumatran Elephent', 'Sumatran Orang-uta', 'Sumatran Rhinocros', 'Sumatran Tige', 'Sun Bar', 'Swai Fihs', 'Swa', 'Swedish Vallhun', 'Tamaska', 'Tan', 'Tapanuli Orang-uta', 'Tapi', 'Tarpo', 'Tarsie', 'Tasmanian Devi', 'Tawny Ow', 'Teddy Roosevelt Terrir', 'Termit', 'Tetra', 'Thorny Devi', 'Tibetan Mastif', 'Tiffan', 'Tige', 'Tiger Salamande', 'Tiger Shar', 'Tortois', 'Touca', 'Tree Fro', 'Tropicbir', 'Tuatar', 'Turke', 'Turkish Angor', 'Uakar', 'Uguis', 'Umbrellabir', 'Utonaga', 'Vampire Ba', 'Vampire Squi', 'Vaquita', 'Vervet Monke', 'Vultur', 'Wallab', 'Walleye Fihs', 'Walru', 'Wandering Albatros', 'Wartho', 'Was', 'Water Buffal', 'Water Drgaon', 'Water Vol', 'Wease', 'Welsh Corgi: The Complete Pet Guid', 'West Highland Terrir', 'Western Gorila', 'Western Lowland Gorila', 'Whale Shar', 'Whippe', 'White Rhinocros', 'White Tige', 'White-Faced Capuchi', 'Wild Boa', 'Wildebees', 'Wol', 'Wolf Eel', 'Wolf Spide', 'Wolffsh', 'Wolverin', 'Womba', 'Woodlous', 'Woodpecke', 'Woolly Mamoth', 'Woolly Monke', 'Wrass', 'Wyoming Toa', 'X-Ray Tetra', 'Xeru', 'Ya', 'Yellow-Eyed Pengin', 'Yorkshire Terrir', 'Zebr', 'Zebra Shar', 'Zebu', 'Zonke', 'Zors']
treinta = ['Ardvark', 'Abyssna', 'Adeli Penuin', 'Affnpischer', 'Afgan Hnoud', 'Africn Buhs Elepht', 'Africn Cvet', 'Africn Cawed Frog', 'Africn Frest Elepht', 'Africn Plam Civt', 'Africn Pengi', 'Africn Tre Toad', 'Africn Wild Dog', 'Ainu Dog', 'Aiedale Trrier', 'Akbsh', 'Aita', 'Alaskan Mlamute', 'Albtross', 'Aldabra Giatn Totoise', 'Alligatr', 'Alpca', 'Alpin Dachsbrak', 'Amazn Rver Dolpin (Pik Dolpin)', 'Amercan Alsaian', 'Amercan Bllodg', 'Amercan Ccker Spnail', 'Amercan Conhoud', 'Amercan Esimo Dog', 'Amercan Foxhond', 'Amercan Pit Bul Trrier', 'Amercan Stfforshire Trrier', 'Amercan Wter Spnail', 'Amur Leopaord', 'Anatolin Sheperd Dog', 'Ancvhies', 'Angelfih', 'Ant', 'Anteatr', 'Antelop', 'Appenzller Dog', 'Araaima', 'Arcti Fox', 'Arcti Hare', 'Arcti Wolf', 'Armadilo', 'Asian Elphent', 'Asian Gaint Hornt', 'Asian Plam Civt', 'Asatic Blac Bar', 'Aurcohs', 'Austrlian Catle Dog', 'Austrlian Kelpi Dog', 'Austrlian Mit', 'Austrlian Shepher', 'Austrlian Trrier', 'Avcet', 'Axoltl', 'Aye Aye', 'Baboon', 'Bactrian Camle', 'Badgr', 'Baij', 'Balinese', 'Banded Plam Civt', 'Bandicot', 'Barb', 'Barn Owl', 'Barnacl', 'Barracuda', 'Barramundi Fih', 'Basenji Dog', 'Baskin Shar', 'Basset Fauv de Bretagn', 'Basset Houn', 'Bat', 'Bavarin Mounatin Houn', 'Beagl', 'Bar', 'Bearded Colie', 'Bearded Drgaon', 'Beavr', 'Bedlingon Trrier', 'Beelt', 'Beluga Sturegon', 'Bengl Tiger', 'Bernse Mountian Dog', 'Bchir', 'Bichon Fris', 'Biewer Trrier', 'Binturong', 'Brd', 'Bids Of Pradise', 'Birman', 'Bison', 'Blak Marlin', 'Blak Rhinceros', 'Blak Russin Trrier', 'Blak Widow Spide', 'Blobfih', 'Bloohund', 'Blu Jay', 'Blu Lacy Dog', 'Blu Whal', 'Bluetick Conhoud', 'Bobat', 'Bolognes Dog', 'Bomay', 'Bongo', 'Bonito Fih', 'Bonobo', 'Booby', 'Border Colie', 'Border Trrier', 'Bornean Orag-utan', 'Borneo Elphent', 'Bston Trrier: Complt Pet Guid', 'Bottlense Dolpin', 'Bowfin', 'Bowhed Whal', 'Boxer Dog', 'Boykin Spnail', 'Brazlian Trrier', 'Britih Timbe', 'Brown Bar', 'Budgerigar', 'Buffal', 'Bul Shar', 'Bul Trrier', 'Buldog', 'Bulforg', 'Bulmastif', 'Bumbleb', 'Burmes', 'Burroing Fog', 'Buterfly', 'Buterfly Fih', 'Caiman', 'Caiman Lizrd', 'Cairn Trrier', 'Camel', 'Camel Spide', 'Canaan Dog', 'Canadin Esimo Dog', 'Capybara', 'Caracl', 'Carolin Dog', 'Carp', 'Cassowary', 'Cat', 'Caterpilar', 'Catfih', 'Cavalier King Charls Spnail', 'Centiped', 'Cesky Fousk', 'Chameleo', 'Chamo', 'Cheeth', 'Chesapeak Bay Retrivr', 'Chiken', 'Chihahua', 'Chimaer', 'Chimpanz', 'Chinchila', 'Chinse Cresetd Dog', 'Chinok', 'Chinstrp Pengi', 'Chipmunk', 'Chow Cho', 'Cichli', 'Cloude Leopaord', 'Clownfih', 'Clumber Spnail', 'Coati', 'Cockato', 'Cockroach', 'Coelacanth', 'Colard Peccary', 'Colie', 'Colosal Squi', 'Comon Buzard', 'Comon Fog', 'Comon Loon', 'Comon Toad', 'Cooper’s Haw', 'Coral', 'Cotton-top Tamarin', 'Cougar', 'Cow', 'Coyot', 'Crab', 'Crab-Eatin Macaqu', 'Crane', 'Crested Pengi', 'Crocodil', 'Cros Rver Gorila', 'Curly Coatd Retrivr', 'Cuscu', 'Cutlefih', 'Dachsun', 'Dalmatin', 'Darwin’s Fog', 'Deer', 'Desrt Totoise', 'Deutche Brack', 'Dole', 'Dingo', 'Discu', 'Doberman Pinsche', 'Dod', 'Dog', 'Dogo Argetin', 'Dogue De Bordux', 'Dolpin', 'Donke', 'Dormous', 'Dragonfih', 'Dragonf', 'Drever', 'Drum Fih', 'Duck', 'Dugong', 'Dunke', 'Dusky Dolpin', 'Dwarf Crocodil', 'Eagl', 'Earwig', 'Eatern Gorila', 'Eatern Lowland Gorila', 'Echidn', 'Edibl Fog', 'Eel', 'Egyptan Mau', 'Electri Eel', 'Elepht', 'Elepht Sea', 'Elepht Shre', 'Emperor Pengi', 'Emperor Tamar', 'Emu', 'Englih Ccker Spnail', 'Englih Shepher', 'Englih Sprnger Spnail', 'Entlebucher Mounatin Dog', 'Epagneul Pont Audem', 'Ermine', 'Esimo Dog', 'Estrela Mounatin Dog', 'Falco', 'Fals Kiler Whal', 'Fangtoth', 'Fennec Fo', 'Feret', 'Field Spnail', 'Fin Whal', 'Finnih Spizt', 'Fire-Belied Toad', 'Fih', 'Fishin Cat', 'Flamigo', 'Flat Coat Retrivr', 'Flound', 'Fluk Fih (sumer flouner)', 'Fly', 'Flyin Squirre', 'Foss', 'Fo', 'Fox Trrier', 'Frenh Buldog', 'Frigatebir', 'Frilled Lizrd', 'Frilled Shar', 'Fog', 'Fur Sea', 'Galapagos Pengi', 'Galapagos Totoise', 'Gar', 'Gecko', 'Gento Pengi', 'Geoffroys Tamar', 'Gerbil', 'German Pinsche', 'German Sheperd Guid', 'Gharia', 'Giant Africn Land Snail', 'Giant Clam', 'Giant Panda Bar', 'Giant Schnauze', 'Gibon', 'Gila Monste', 'Giraf', 'Glas Lizrd', 'Glow Wom', 'Goat', 'Goblin Shar', 'Golden Lion Tamar', 'Golden Maske Ow', 'Golden Oiol', 'Golden Retrievr Complt Pet Guid', 'Golden-Crowned Flyin Fo', 'Goos', 'Gophe', 'Gorila', 'Graschoppe', 'Great Dan', 'Great Pyrnees', 'Great Whit Shar', 'Greater Swis Mounatin Dog', 'Green Anol', 'Green Be-Eate', 'Greenland Dog', 'Grey Mous Lemur', 'Grey Reef Shar', 'Grey Sea', 'Greyhound', 'Grizzly Bar', 'Grouse', 'Guinea Fow', 'Guinea Pi', 'Guppy', 'Hagfih', 'Hammerhed Shar', 'Hamste', 'Hare', 'Harpy Eagl', 'Harrie', 'Havanes', 'Hawaiian Cro', 'Hedgeho', 'Herclues Beetl', 'Hermit Crab', 'Heron', 'Herring', 'Highland Catle', 'Himalayan', 'Hippopotam', 'Honey Badgr', 'Honey Be', 'Hoopo', 'Horn Shar', 'Hornbil', 'Horned Fog', 'Hors', 'Horseshoe Cra', 'Howler Monke', 'Human', 'Humboldt Pengi', 'Hummingbir', 'Humpbak Whal', 'Hyen', 'Ibi', 'Ibizan Houn', 'Iguan', 'Imortal Jellyfih', 'Impal', 'Indian Elphent', 'Indian Plam Squirre', 'Indian Rhinceros', 'Indian Star Totoise', 'Indochinse Tige', 'Indri', 'Insec', 'Irish Settr Complt Pet Guid', 'Irish WolfHoun', 'Italian Greyhoun', 'Jack Russe', 'Jacka', 'Jaguar', 'Japnese Chin', 'Japnese Macaqu', 'Javan Rhinceros', 'Javanes', 'Jellyfih', 'Jerboa', 'Kakapo', 'Kangar', 'Keel-Biled Touca', 'Keeshon', 'Kiler Whal', 'King Cobr', 'King Cra', 'King Pengi', 'Kingfishe', 'Kiw', 'Koal', 'Komodo Drgaon', 'Kril', 'Kud', 'Labradodl', 'Labrador Retrivr', 'Ladyb', 'Lamprey', 'Leaf-Taied Geck', 'Leming', 'Lemur', 'Leopaord', 'Leopaord Cat', 'Leopaord Sea', 'Leopaord Totoise', 'Lige', 'Lion', 'Lionfih', 'Litle Pengi', 'Lizrd', 'Llam', 'Lobste', 'Long-Eared Ow', 'Lungfih', 'Lyn', 'Macaroni Pengi', 'Macaw', 'Magellanic Pengi', 'Magp', 'Maine Coon', 'Malayan Civt', 'Malayan Tige', 'Malte', 'Mama', 'Manate', 'Mandril', 'Maned Wol', 'Manta Ra', 'Marin Toa', 'Markho', 'Marmo', 'Marsh Fog', 'Masked Plam Civt', 'Mastif', 'Mayf', 'Meerkat', 'Megalodon', 'Mexican Fre-Taied Ba', 'Milkfih', 'Milliped', 'Min', 'Minke Whal', 'Mol', 'Mol', 'Monarh Buterfly', 'Mongoos', 'Mongre', 'Monitr Lizrd', 'Monke', 'Monkfih', 'Monte Iberia Eleth', 'Moorhen', 'Moos', 'Moray Eel', 'Mot', 'Mountin Gorila', 'Mountin Lio', 'Mous', 'Mul', 'Muskra', 'Narwhal', 'Neandertha', 'Neapolitn Mastif', 'Newfoundlan', 'Newt', 'Nightingal', 'Norfolk Trrier', 'North Amercan Blac Bar', 'Norhern Inuit Dog', 'Norwegian Fores', 'Numbat', 'Nurse Shar', 'Ocelot', 'Octopus', 'Okapi', 'Old Englih Sheepdo', 'Olm', 'Oposum', 'Orag-utan', 'Ostric', 'Ote', 'Oyste', 'Paddlefih', 'Pademelon', 'Pangolin', 'Panthe', 'Parot', 'Patas Monke', 'Peacock', 'Pekines', 'Pelica', 'Pengi', 'Pere Davids De', 'Peregrin Falco', 'Persian', 'Petit Basset Grifon Vendée', 'Pheasan', 'Pied Tamar', 'Pi', 'Pik', 'Pike Fih', 'Pink Fairy Armadilo', 'Piranha', 'Platyp', 'Pointe', 'Poison Dart Fog', 'Polar Bar', 'Pond Skate', 'Poodl', 'Pool Fog', 'Porcupin', 'Porpois', 'Posum', 'Prawn', 'Proboscis Monke', 'Pufferfih', 'Puffin', 'Pu', 'Pum', 'Purpl Emperor Buterfly', 'Pus Mot', 'Pygmy Hippopotam', 'Pygmy Marmos', 'Quai', 'Quetz', 'Quokk', 'Quol', 'Rabbi', 'Raccoo', 'Raccoon Dog', 'Radiatd Totoise', 'Ragdol', 'Ra', 'Rattlesnak', 'Red Finch', 'Red Fo', 'Red Kne Tarantul', 'Red Pand', 'Red Wol', 'Red-handed Tamar', 'Reindeer', 'Rhincero', 'Rver Turtl', 'Robin', 'Rock Hyra', 'Rockfih', 'Rockhopper Pengi', 'Roseate Spoonbil', 'Rottweile', 'Royal Pengi', 'Russin Blu', 'Saarlos Wolfdo', 'Saber-Toothe Tige', 'Sabl', 'Saig', 'Saint Berna', 'Salamande', 'Salmo', 'Samoye', 'Sand Lizrd', 'Sao', 'Sardin', 'Sawfih', 'Scimitar-horne Ory', 'Scorpion', 'Scorpion Fih', 'Sea Drgaon', 'Sea Lio', 'Sea Ote', 'Sea Slu', 'Sea Squir', 'Sea Turtl', 'Sea Urchin', 'Seahors', 'Sea', 'Serv', 'Shar', 'Shee', 'Shiba Inu', 'Shih Tze', 'Shrimp', 'Siames', 'Siamese Fightin Fih', 'Siberian', 'Siberian Husk', 'Siberian Tige', 'Silver Dolla', 'Skate Fih', 'Skun', 'Slot', 'Slow Wom', 'Snail', 'Snak', 'Snaping Turtl', 'Snowsho', 'Snowy Ow', 'Somal', 'South Chin Tige', 'Spadefot Toa', 'Sparro', 'Spectacled Bar', 'Sperm Whal', 'Spider Monke', 'Spiny Dogfih', 'Spixs Maca', 'Spong', 'Squi', 'Squirre', 'Squirrel Monke', 'Sri Lankan Elphent', 'Staffordshire Bul Trrier', 'Stag Beetl', 'Starfih', 'Steller’s Sea Co', 'Stic Insec', 'Stingr', 'Stoa', 'Striped Rocket Fog', 'Sturegon', 'Sucker Fih', 'Sugar Glide', 'Sumatran Elphent', 'Sumatran Orag-utan', 'Sumatran Rhinceros', 'Sumatran Tige', 'Sun Bar', 'Swai Fih', 'Swa', 'Swedih Vallhun', 'Tamask', 'Tan', 'Tapanul Orag-utan', 'Tapi', 'Tarpo', 'Tarsie', 'Tasmanian Devi', 'Tawny Ow', 'Teddy Roosevelt Trrier', 'Termit', 'Tetra', 'Thorny Devi', 'Tibetan Mastif', 'Tiffan', 'Tige', 'Tiger Salamande', 'Tiger Shar', 'Totoise', 'Touca', 'Tre Fog', 'Tropicbir', 'Tuatar', 'Turke', 'Turkih Angor', 'Uakar', 'Uguis', 'Umbrellabir', 'Utonaga', 'Vampire Ba', 'Vampire Squi', 'Vaquita', 'Vervet Monke', 'Vultur', 'Wallab', 'Walleye Fih', 'Walru', 'Wanderin Albatros', 'Wartho', 'Was', 'Water Buffal', 'Water Drgaon', 'Water Vol', 'Weas', 'Welsh Corgi: The Complt Pet Guid', 'West Highlad Trrier', 'Western Gorila', 'Western Lowlad Gorila', 'Whale Shar', 'Whippe', 'White Rhinceros', 'White Tige', 'White-Faced Capuchi', 'Wild Boa', 'Wildebee', 'Wol', 'Wolf Eel', 'Wolf Spide', 'Wolffih', 'Wolverin', 'Womba', 'Woodlous', 'Woodpecke', 'Woolly Mamoth', 'Woolly Monke', 'Wrass', 'Wyomin Toa', 'X-Ray Tetra', 'Xeru', 'Ya', 'Yellow-Eyed Pengi', 'Yorkshir Trrier', 'Zebr', 'Zebra Shar', 'Zebu', 'Zonke', 'Zors']
cincuenta = ['Ardvak', 'Abyssna', 'Adel Penu', 'Affnpice', 'Afgn Hnoud', 'Afirn Buhs Elep', 'Afirn Cvet', 'Afirn Cwed Fog', 'Afirn Frst Elep', 'Afirn Plm Civt', 'Afirn Peng', 'Afirn Tre Tod', 'Afirn Wild Og', 'Aiu Og', 'Aiedle Trre', 'Akbh', 'Aita', 'Alasn Mlamt', 'Albtos', 'Aldar Giat Ttoie', 'Allgat', 'Alpa', 'Alpi Dachbra', 'Amazn Rve Dolp (Pik Dolp)', 'Amrcn Alsaia', 'Amrcn Bllod', 'Amrcn Cce Spnai', 'Amrcn Conhou', 'Amrcn Eimo Og', 'Amrcn Foxhon', 'Amrcn Pit Bu Trre', 'Amrcn Stffosie Trre', 'Amrcn Wte Spnai', 'Amr Leopaod', 'Anatoin Shepe Og', 'Anvhie', 'Anglfih', 'Ant', 'Anteat', 'Antelp', 'Appnzlle Og', 'Araaim', 'Arci Fo', 'Arci Har', 'Arci Wolf', 'Armail', 'Asia Elpht', 'Asia Giat Hornt', 'Asia Plm Civt', 'Asaic Blc Ba', 'Aurco', 'Austrlia Catl Og', 'Austrlia Kelp Og', 'Austrlia Mit', 'Austrlia Shephe', 'Austrlia Trre', 'Avct', 'Axoltl', 'Aye Ay', 'Baboo', 'Bactria Caml', 'Badg', 'Bai', 'Balins', 'Bande Plm Civt', 'Bandiot', 'Bab', 'Ban Owl', 'Barncl', 'Barracud', 'Baramuni Fih', 'Basnj Og', 'Baski Sha', 'Basset Fau De Btag', 'Basset Hou', 'Ba', 'Bavain Mounai Hou', 'Beag', 'Ba', 'Beare Coli', 'Beare Drgao', 'Beav', 'Bedlingo Trre', 'Beel', 'Belug Stregon', 'Beng Tige', 'Berns Mounai Og', 'Bchi', 'Bicho Fri', 'Biewe Trre', 'Binturog', 'Bd', 'Bids Of Prdise', 'Brma', 'Biso', 'Blak Malin', 'Blak Rhinceo', 'Blak Russi Trre', 'Blak Wdow Spie', 'Blobfih', 'Bloohun', 'Bl Jay', 'Bl Lacy Og', 'Bl Whal', 'Bluetick Conhou', 'Bobat', 'Bologne Og', 'Bomay', 'Bong', 'Bonit Fi', 'Bonob', 'Boob', 'Borde Coli', 'Borde Trre', 'Bornea Orag-uta', 'Borne Elpht', 'Bsto Trre: Comlt Pe Gui', 'Bottlnse Dolpi', 'Bowfi', 'Bowhe Wha', 'Boxe Og', 'Boyki Spnai', 'Brazlia Trre', 'Briti Timb', 'Brow Ba', 'Budgeiga', 'Buffa', 'Bu Sha', 'Bu Trre', 'Buldg', 'Bulfor', 'Bulmastf', 'Bumble', 'Brme', 'Burroin Fo', 'Butefly', 'Buteffy Fi', 'Caima', 'Caima Lizr', 'Cair Trre', 'Came', 'Came Spie', 'Canaa Og', 'Canadi Eimo Og', 'Capybara', 'Caracl', 'Caroli Og', 'Cap', 'Cassoway', 'Ca', 'Caterpila', 'Catfi', 'Cavalie Kin Charl Spnai', 'Centipe', 'Cesky Fous', 'Chamele', 'Cham', 'Cheet', 'Chesapea Ba Retriv', 'Chike', 'Chihaua', 'Chimae', 'Chimpan', 'Chinchil', 'Chinse Creetd Og', 'Chinok', 'Chinstr Peng', 'Chipmun', 'Chow C', 'Cichl', 'Cloud Leopaod', 'Clownfi', 'Clumbe Spnai', 'Coat', 'Cockat', 'Cockroac', 'Coelacant', 'Colar Pecca', 'Coli', 'Colosa Squ', 'Como Buza', 'Como Fo', 'Como Loo', 'Como Toa', 'Coope’ Haw', 'Cora', 'Cotto-top Tama', 'Couga', 'Co', 'Coyo', 'Crab', 'Crab-Eati Macaq', 'Cran', 'Creste Peng', 'Crocodi', 'Cro Rve Gorila', 'Curl Coatd Retriv', 'Cusc', 'Cutlefi', 'Dachsu', 'Dalmat', 'Darwin’ Fo', 'Dee', 'Desr Ttoise', 'Deutch Brac', 'Dol', 'Ding', 'Dis', 'Doberma Pinsch', 'Do', 'Do', 'Dogo Arget', 'Dogue D Bordu', 'Dolpi', 'Donk', 'Dormou', 'Dragonfi', 'Dragon', 'Dreve', 'Dru Fi', 'Duc', 'Dugon', 'Dunk', 'Dusk Dolpi', 'Dwarf Crocodi', 'Eag', 'Earwi', 'Easte Gorila', 'Easte Lowlan Gorila', 'Echid', 'Edibl Fo', 'Ee', 'Egypa Ma', 'Electr Ee', 'Elepht', 'Elepht Se', 'Elepht Shr', 'Empero Peng', 'Empero Tama', 'Em', 'Engli Ccke Spnai', 'Engli Shephe', 'Engli Sprnge Spnai', 'Entlebche Mounai Og', 'Epagneu Pon Aude', 'Ermin', 'Eimo Og', 'Estrel Mounai Og', 'Falco', 'Fals Kile Wha', 'Fangtot', 'Fennec F', 'Fere', 'Fiel Spnai', 'Fi Wha', 'Finnih Spi', 'Fire-Beied Toa', 'Fih', 'Fishi Ca', 'Flamig', 'Flat Coat Retriv', 'Floun', 'Fluk Fi (sue floune)', 'Fl', 'Flyi Squirr', 'Fos', 'F', 'Fo Trre', 'Fren Buldog', 'Frigatebi', 'Frille Lizr', 'Frille Sha', 'Fo', 'Fu Se', 'Galapago Peng', 'Galapago Ttoise', 'Ga', 'Geck', 'Gent Peng', 'Geoffroy Tama', 'Gerbi', 'Germa Pinsch', 'Germa Sheper Gui', 'Gharia', 'Gian Afric Lan Snai', 'Gian Cla', 'Gian Pand Ba', 'Gian Schnauz', 'Gibo', 'Gil Monst', 'Gira', 'Gla Lizr', 'Glow Wo', 'Goa', 'Gobli Sha', 'Gole Lio Tama', 'Gole Mask Ow', 'Gole Oio', 'Gole Retriev Coml Pe Gui', 'Gole-Crowne Flyi F', 'Goo', 'Goph', 'Gorila', 'Graschopp', 'Grea Da', 'Grea Pyrnee', 'Grea Whit Sha', 'Greate Swi Mounai Og', 'Gree Ano', 'Gree B-Eat', 'Greenlan Og', 'Gre Mou Lemu', 'Gre Ree Sha', 'Gre Se', 'Greyhoun', 'Grizzl Ba', 'Grous', 'Guinea Fo', 'Guinea P', 'Gupp', 'Hagfi', 'Hammerhe Sha', 'Hamst', 'Har', 'Harp Eag', 'Harri', 'Havane', 'Hawaiia Cr', 'Hedgeh', 'Herclue Beet', 'Hermi Cra', 'Hero', 'Herin', 'Highlan Catl', 'Himalaya', 'Hippopotam', 'Hone Badg', 'Hone B', 'Hoop', 'Hor Sha', 'Hornbi', 'Horne Fo', 'Hor', 'Horsesho Cr', 'Howle Monk', 'Huma', 'Humbold Peng', 'Hummingbi', 'Humpba Wha', 'Hye', 'Ib', 'Ibiza Hou', 'Igua', 'Imorta Jellyfi', 'Impa', 'India Elpht', 'India Pla Squirr', 'India Rhincero', 'India Sta Ttoise', 'Indochins Tig', 'Indr', 'Inse', 'Iris Sett Coml Pe Gui', 'Iris WolfHou', 'Italia Greyhou', 'Jac Russ', 'Jack', 'Jaguar', 'Japnes Chi', 'Japnes Macaq', 'Java Rhincero', 'Javane', 'Jellyfi', 'Jerbo', 'Kakap', 'Kanga', 'Keel-Bile Touc', 'Keesho', 'Kile Wha', 'Kin Cob', 'Kin Cra', 'Kin Peng', 'Kingfish', 'Ki', 'Koal', 'Komod Drgao', 'Kri', 'Ku', 'Labradod', 'Labrado Retriv', 'Lady', 'Lampey', 'Leaf-Taie Gec', 'Lemin', 'Lemu', 'Leopaod', 'Leopaod Ca', 'Leopaod Se', 'Leopaod Ttoise', 'Lig', 'Lio', 'Lionfi', 'Littl Peng', 'Lizr', 'Lla', 'Lobste', 'Long-Eare O', 'Lungfi', 'Ly', 'Macaro Peng', 'Macw', 'Magellani Peng', 'Mag', 'Main Coo', 'Malay Civ', 'Malay Tig', 'Malt', 'Mam', 'Manat', 'Mandri', 'Mane Wo', 'Mant R', 'Mari To', 'Markh', 'Marm', 'Mars Fo', 'Maske Pla Civ', 'Masti', 'May', 'Meerka', 'Megalo', 'Mexica Fre-Taie B', 'Milkfi', 'Millipe', 'Mi', 'Mink Wha', 'Mo', 'Mo', 'Monar Buteffy', 'Mongo', 'Mongr', 'Monit Lizr', 'Monk', 'Monkfi', 'Mont Iberia Ele', 'Moorhe', 'Moo', 'Mora Ee', 'Mo', 'Mounti Gorila', 'Mounti Li', 'Mou', 'Mu', 'Muskr', 'Narwha', 'Neandeth', 'Neapolitn Masti', 'Newfoundla', 'New', 'Nightinga', 'Norfol Trre', 'North Amrca Bla Ba', 'Northe Inui Do', 'Norwegia Fore', 'Numat', 'Nurs Sha', 'Ocelo', 'Octopu', 'Okap', 'Ol Engli Sheepd', 'Ol', 'Oposu', 'Orag-uta', 'Ostri', 'Ot', 'Oyst', 'Paddlefi', 'Pademelo', 'Pangoli', 'Pant', 'Paro', 'Pata Monk', 'Peaco', 'Pekin', 'Pelic', 'Peng', 'Pere David D', 'Peregri Falc', 'Persia', 'Peti Basset Grifo Vend', 'Pheasa', 'Pie Tama', 'P', 'Pi', 'Pik Fi', 'Pin Fair Armail', 'Piranha', 'Platyp', 'Point', 'Poiso Dar Fo', 'Pola Ba', 'Pon Skat', 'Pood', 'Poo Fo', 'Porcupi', 'Porpoi', 'Posu', 'Praw', 'Probosci Monk', 'Pufferfi', 'Puffi', 'P', 'Pu', 'Purp Empero Buteffy', 'Pu Mo', 'Pygm Hippopotam', 'Pygm Marmo', 'Qua', 'Quetz', 'Quok', 'Quo', 'Rab', 'Racco', 'Raccoo Do', 'Radiate Ttoise', 'Ragdo', 'R', 'Rattlesna', 'Re Fin', 'Re F', 'Re Kne Tarantu', 'Re Pan', 'Re Wo', 'Re-hande Tama', 'Reinde', 'Rhincer', 'Rve Turt', 'Robi', 'Roc Hyr', 'Rocfi', 'Rockhoppe Peng', 'Roseat Spoonbi', 'Rottweil', 'Roya Peng', 'Russin Bl', 'Saarloo Wolfd', 'Saber-Toothe Tig', 'Sab', 'Sai', 'Sain Bern', 'Salamand', 'Salm', 'Samoy', 'San Lizr', 'Sa', 'Sardi', 'Sawfi', 'Scimitar-horn Or', 'Scorpio', 'Scorpio Fi', 'Sea Drgao', 'Sea Li', 'Sea Ot', 'Sea Sl', 'Sea Squi', 'Sea Turt', 'Sea Urchi', 'Seahor', 'Se', 'Serv', 'Sha', 'She', 'Shib In', 'Shih Tz', 'Shrim', 'Siame', 'Siames Fighti Fi', 'Siberia', 'Siberia Hus', 'Siberia Tig', 'Silve Dolla', 'Skat Fi', 'Sku', 'Slo', 'Slo Wo', 'Sna', 'Sna', 'Snapin Turt', 'Snowsh', 'Snowy O', 'Soma', 'Sout Chin Tig', 'Spadefo To', 'Sparr', 'Spectacle Ba', 'Sper Wha', 'Spide Monk', 'Spiny Dogfi', 'Spix Mac', 'Spon', 'Squ', 'Squirr', 'Squirre Monk', 'Sri Lanka Elepht', 'Stafforshir Bu Trre', 'Sta Beet', 'Starfi', 'Steller’ Se C', 'Sti Inse', 'Sting', 'Sto', 'Stripe Rocke Fo', 'Sturego', 'Sucke Fi', 'Suga Glid', 'Sumatra Elepht', 'Sumatra Orag-uta', 'Sumatra Rhincero', 'Sumatra Tig', 'Su Ba', 'Swa Fi', 'Sw', 'Swedi Vallhu', 'Tamask', 'Ta', 'Tapanu Orag-uta', 'Tap', 'Tarpo', 'Tarsie', 'Tasmania Dev', 'Tawny O', 'Teddy Roosevel Trre', 'Termi', 'Tetra', 'Thorny Dev', 'Tibeta Masti', 'Tiffa', 'Tig', 'Tige Salamand', 'Tige Sha', 'Ttoise', 'Touc', 'Tre Fo', 'Tropicbi', 'Tuata', 'Turk', 'Turki Ango', 'Uaka', 'Ugui', 'Umbrellabi', 'Utonag', 'Vampir B', 'Vampir Squ', 'Vaquita', 'Verve Monk', 'Vultu', 'Wallab', 'Walley Fi', 'Walr', 'Wanderi Albtro', 'Warth', 'Wa', 'Wate Buffa', 'Wate Drgao', 'Wate Vo', 'Wea', 'Wels Corgi: Th Coml Pe Gui', 'Wes Highla Trre', 'Weste Gorila', 'Weste Lowla Gorila', 'Whal Sha', 'Whippe', 'Whit Rhincero', 'Whit Tig', 'White-Face Capuch', 'Wil Bo', 'Wildebe', 'Wo', 'Wolf Ee', 'Wolf Spie', 'Wolffi', 'Wolveri', 'Womb', 'Woodlou', 'Woodpeck', 'Wooll Mamot', 'Wooll Monk', 'Wras', 'Wyomi To', 'X-Ra Tetr', 'Xer', 'Y', 'Yellow-Eye Peng', 'Yorkshi Trre', 'Zebr', 'Zebra Sha', 'Zeb', 'Zonk', 'Zors']
setentaicinco = ['Ardv', 'Abysn', 'Adel Pnu', 'Affnpic', 'Afgn Hno', 'Afirn Buh Elp', 'Afirn Cv', 'Afirn Cwe Fo', 'Afirn Frs Ele', 'Afirn Plm Civ', 'Afirn Pen', 'Afirn Tr To', 'Afirn Wil O', 'Aiu O', 'Aiedl Trr', 'Akb', 'Ait', 'Alas Mlam', 'Albt', 'Alda Gia Tto', 'Allga', 'Alp', 'Alp Dacsbra', 'Amn Rv Dol (Pi Dol)', 'Amrc Alsai', 'Amrc Bllod', 'Amrc Cc Spna', 'Amrc Conho', 'Amrc Eim O', 'Amrc Foxho', 'Amrc Pi B Trr', 'Amrc Stffosi Trr', 'Amrc Wt Spna', 'Amr Leopao', 'Anatoi Shep O', 'Anvhi', 'Anglf', 'An', 'Anteat', 'Antel', 'Appnzll O', 'Araai', 'Arc F', 'Arc Ha', 'Arc Wol', 'Armai', 'Asi Elph', 'Asi Gia Hor', 'Asi Plm Civ', 'Asai Bl B', 'Aurc', 'Austrli Cat O', 'Austrli Kel O', 'Austrli Mi', 'Austrli Sheph', 'Austrli Trr', 'Avc', 'Axol', 'Ay A', 'Babo', 'Bactri Cam', 'Bad', 'Ba', 'Balin', 'Band Plm Civ', 'Bandio', 'Ba', 'Ba Ow', 'Barnc', 'Barracu', 'Baramun Fi', 'Basn O', 'Bask Sh', 'Bass Fau D Bta', 'Bass Ho', 'B', 'Bavai Mouna Ho', 'Bea', 'B', 'Bear Col', 'Bear Drga', 'Bea', 'Bedling T', 'Bee', 'Belu Strego', 'Ben Tig', 'Berns Mouna O', 'Bch', 'Bich Fr', 'Biew T', 'Binturo', 'B', 'Bid O Prdise', 'Brm', 'Bis', 'Bla Mali', 'Bla Rhince', 'Bla Russ T', 'Bla Wdo Spi', 'Blobfi', 'Bloohu', 'B J', 'B Lac O', 'B Wha', 'Blueti Conho', 'Boba', 'Bologn O', 'Boma', 'Bon', 'Boni F', 'Bon', 'Boo', 'Bord Col', 'Bord Trr', 'Borne Ora-uta', 'Born Elph', 'Bst Trr: Coml P Gu', 'Bottlns Dolp', 'Bowf', 'Bowh Wh', 'Box O', 'Boyk Spna', 'Brazli Trr', 'Brit Timb', 'Bro B', 'Budgeig', 'Buff', 'B Sh', 'B Trr', 'Buldo', 'Bulfo', 'Bulmast', 'Bumb', 'Brm', 'Burroi F', 'Butefl', 'Butefy F', 'Caim', 'Caim Liz', 'Cai Trr', 'Cam', 'Cam Spi', 'Cana O', 'Canad Eim O', 'Capybar', 'Carac', 'Carol O', 'Ca', 'Cassowa', 'C', 'Caterpil', 'Catf', 'Cavali Ki Char Spna', 'Centip', 'Cesk Fou', 'Chamele', 'Cham', 'Chee', 'Chesape B Retri', 'Chik', 'Chihau', 'Chima', 'Chimpa', 'Chinchi', 'Chins Creet O', 'Chino', 'Chinst Pen', 'Chipmun', 'Chow', 'Cich', 'Clou Leopao', 'Clownf', 'Clumb Spna', 'Coa', 'Cocka', 'Cockroac', 'Coelacan', 'Cola Pecca', 'Col', 'Colos Sq', 'Com Buz', 'Com F', 'Com Lo', 'Com To', 'Coope Ha', 'Cor', 'Cotto-to Tam', 'Coug', 'C', 'Coy', 'Cra', 'Crab-Eat Maca', 'Cra', 'Crest Pen', 'Crocod', 'Cr Rv Goril', 'Crl Coatd Retri', 'Cus', 'Cutlef', 'Dachs', 'Dalma', 'Darwin F', 'De', 'Des Ttois', 'Deutc Bra', 'Do', 'Din', 'Di', 'Doberm Pins', 'D', 'D', 'Dog Arge', 'Dogu D Bord', 'Dolp', 'Don', 'Dormo', 'Dragonf', 'Drago', 'Drev', 'Dr F', 'Du', 'Dugo', 'Dun', 'Dus Dolp', 'Dwar Crocod', 'Ea', 'Earw', 'East Goril', 'East Lowla Goril', 'Echi', 'Edib F', 'E', 'Egyp M', 'Electr E', 'Eleph', 'Eleph S', 'Eleph Sh', 'Emper Pen', 'Emper Tam', 'E', 'Engl Cck Spna', 'Engl Sheph', 'Engl Sprng Spna', 'Entlebch Mouna O', 'Epagne Po Aud', 'Ermi', 'Eim O', 'Estre Mouna O', 'Falc', 'Fals Kil Wh', 'Fangto', 'Fenne F', 'Fer', 'Fie Spna', 'F Wha', 'Finn Sp', 'Fire-Bei Toa', 'Fi', 'Fish C', 'Flami', 'Fla Coa Retri', 'Flou', 'Flu F (su Floun)', 'F', 'Fly Squir', 'Fo', 'F', 'F Trr', 'Fren Buldo', 'Frigateb', 'Frill Liz', 'Frill Sh', 'F', 'F S', 'Galapag Pen', 'Galapag Ttois', 'G', 'Gec', 'Gen Pen', 'Geoffro Tam', 'Gerb', 'Germa Pins', 'Germa Shepe Gu', 'Ghari', 'Gia Afric La Sna', 'Gia Cl', 'Gia Pan B', 'Gia Schnau', 'Gib', 'Gi Mons', 'Gir', 'Gla Liz', 'Glo W', 'Go', 'Gobl Sh', 'Gol Li Tam', 'Gol Mas O', 'Gol Oi', 'Gol Retriev Com P Gu', 'Gol-Crown Fly F', 'Go', 'Gop', 'Goril', 'Graschopp', 'Gre D', 'Gre Pyrne', 'Gre Whi Sh', 'Great Swi Mouna O', 'Gre An', 'Gre B-Ea', 'Greenla O', 'Gr Mou Lem', 'Gr Re Sh', 'Gr S', 'Greyhou', 'Grizzl B', 'Grous', 'Guinea F', 'Guinea', 'Gup', 'Hagf', 'Hammerh Sh', 'Hams', 'Ha', 'Har Eag', 'Harr', 'Havan', 'Hawaii C', 'Hedge', 'Herclu Bee', 'Herm Cra', 'Her', 'Heri', 'Highla Cat', 'Himalay', 'Hippopota', 'Hon Bad', 'Hon B', 'Hoo', 'Ho Sh', 'Hornb', 'Horn F', 'Ho', 'Horsesh C', 'Howl Mon', 'Hum', 'Humbold Pen', 'Hummingb', 'Humpb Wh', 'Hy', 'I', 'Ibiz Ho', 'Igu', 'Imort Jellyf', 'Imp', 'India Elph', 'India Pl Squir', 'India Rhincero', 'India St Ttois', 'Indochin Ti', 'Ind', 'Ins', 'Iris Set Com P Gu', 'Iris WolfHo', 'Italia Greyho', 'Jac Rus', 'Jac', 'Jagua', 'Japne Ch', 'Japne Maca', 'Java Rhincero', 'Javan', 'Jellyf', 'Jerb', 'Kaka', 'Kang', 'Keel-Bil Touc', 'Keesh', 'Kil Wh', 'Kin Co', 'Kin Cr', 'Kin Pen', 'Kingfis', 'K', 'Koa', 'Komo Drga', 'Kr', 'K', 'Labrado', 'Labrad Retri', 'Lad', 'Lampe', 'Leaf-Tai Ge', 'Lemi', 'Lem', 'Leopao', 'Leopao C', 'Leopao S', 'Leopao Ttois', 'Li', 'Li', 'Lionf', 'Littl Pen', 'Liz', 'Ll', 'Lobst', 'Long-Ear', 'Lungf', 'L', 'Macar Pen', 'Mac', 'Magellan Pen', 'Ma', 'Mai Co', 'Malay Ci', 'Malay Ti', 'Mal', 'Ma', 'Mana', 'Mandr', 'Man W', 'Man R', 'Mar T', 'Mark', 'Mar', 'Mars F', 'Mask Pl Ci', 'Mast', 'Ma', 'Meerk', 'Megal', 'Mexica Fre-Tai', 'Milkf', 'Millip', 'M', 'Min Wh', 'M', 'M', 'Mona Buteff', 'Mong', 'Mong', 'Monit Liz', 'Mon', 'Monkf', 'Mon Iberi Ele', 'Moorh', 'Mo', 'Mor E', 'M', 'Mounti Goril', 'Mounti L', 'Mo', 'M', 'Musk', 'Narwh', 'Neandert', 'Neapolitn Mast', 'Newfoundl', 'Ne', 'Nighting', 'Norfo Trr', 'North Amrc Bl B', 'North Inu D', 'Norwegia For', 'Numba', 'Nurs Sh', 'Ocel', 'Octop', 'Oka', 'Ol Engl Sheep', 'O', 'Opos', 'Ora-uta', 'Ostr', 'O', 'Oys', 'Paddlef', 'Pademel', 'Pangol', 'Pant', 'Par', 'Pata Mon', 'Peaco', 'Peki', 'Peli', 'Pen', 'Per Davi', 'Peregr Fal', 'Persi', 'Pet Basset Grif Vend', 'Pheasa', 'Pie Tam', '', 'P', 'Pi F', 'Pin Fai Arma', 'Piran', 'Platyp', 'Poin', 'Poiso Da F', 'Pola B', 'Po Ska', 'Poo', 'Poo F', 'Porcup', 'Porpo', 'Pos', 'Pra', 'Probosci Mon', 'Pufferf', 'Puff', 'P', 'P', 'Purp Emper Buteff', 'P M', 'Pygm Hippopota', 'Pygm Marm', 'Qua', 'Quet', 'Quo', 'Quo', 'Ra', 'Racco', 'Racco D', 'Radiat Ttois', 'Ragdo', '', 'Rattlesna', 'R Fi', 'R F', 'R Kn Tarant', 'R Pa', 'R W', 'R-hand Tam', 'Reinde', 'Rhince', 'Rv Tur', 'Rob', 'Ro Hy', 'Rocf', 'Rockhopp Pen', 'Rosea Spoonb', 'Rottwei', 'Roya Pen', 'Russ Bl', 'Saarlo Wol', 'Saber-Toot Ti', 'Sa', 'Sa', 'Sai Ber', 'Salaman', 'Sal', 'Samo', 'Sa Liz', 'S', 'Sard', 'Sawf', 'Scimitar-hor O', 'Scorpi', 'Scorpi F', 'Sea Drga', 'Sea L', 'Sea O', 'Sea S', 'Sea Squ', 'Sea Tur', 'Sea Urch', 'Seaho', 'S', 'Ser', 'Sh', 'Sh', 'Shi In', 'Shi T', 'Shri', 'Siam', 'Siames Fighti F', 'Siberi', 'Siberi Hu', 'Siberi Ti', 'Silv Doll', 'Ska F', 'Sk', 'Sl', 'Sl W', 'Sn', 'Sn', 'Snapin Tur', 'Snows', 'Snow O', 'Som', 'Sout Chi Ti', 'Spadef T', 'Spar', 'Spectacl B', 'Sper Wh', 'Spid Mon', 'Spiny Dogf', 'Spix Ma', 'Spo', 'Sq', 'Squir', 'Squirr Mon', 'Sr Lanka Eleph', 'Stafforshi B Trr', 'Sta Bee', 'Starf', 'Steller’ S C', 'St Inse', 'Stin', 'St', 'Strip Rock Fo', 'Stureg', 'Suck F', 'Sug Gli', 'Sumatr Eleph', 'Sumatr Ora-uta', 'Sumatr Rhincero', 'Sumatr Ti', 'Su B', 'Swa F', 'S', 'Swed Valhu', 'Tamask', 'T', 'Tapanu Ora-uta', 'Ta', 'Tarp', 'Tarsi', 'Tasmania De', 'Tawny', 'Ted Rooseve Trr', 'Term', 'Tetr', 'Thorny De', 'Tibeta Mast', 'Tiffa', 'Ti', 'Tig Salaman', 'Tig Sh', 'Ttois', 'Touc', 'Tr Fo', 'Tropicb', 'Tuat', 'Tur', 'Turk Ang', 'Uaka', 'Ugu', 'Umbrellabi', 'Utonag', 'Vampi B', 'Vampi Squ', 'Vaquita', 'Verv Mon', 'Vultu', 'Wallab', 'Walley F', 'Wal', 'Wanderi Albt', 'Wart', 'W', 'Wat Buff', 'Wat Drga', 'Wat V', 'We', 'Wel Corgi: Th Com P Gu', 'Wes Highla Trr', 'West Goril', 'West Lowl Goril', 'Wha Sha', 'Whippe', 'Whit Rhincero', 'Whit Ti', 'White-Fac Capuc', 'Wil B', 'Wildeb', 'W', 'Wolf E', 'Wolf Spi', 'Wolffi', 'Wolveri', 'Wom', 'Woodlou', 'Woodpec', 'Wooll Mamo', 'Wooll Mon', 'Wra', 'Wyomi T', 'X-Ra Tet', 'Xe', 'Y', 'Yellow-Ey Pen', 'Yorkshi Trr', 'Zebr', 'Zebra Sh', 'Zeb', 'Zon', 'Zor']

errores_diez = 0
errores_treinta = 0
errores_cincuenta = 0
errores_setentaicinco = 0

# %%
for i in range(len(diez)):
    bestMatch = CheckBestMatch(csvFile, diez[i])
    if(bestMatch != csvFile[i]):
        errores_diez += 1
        print("La palabra ingresada fue:",diez[i])
        print("La sugerencia fue "+str(bestMatch)+" pero devio ser "+str(csvFile[i]))
        

print(errores_diez)
# Out:
# La palabra ingresada fue: Dod
# La sugerencia fue Dog pero devio ser Dodo
# La palabra ingresada fue: Zebr
# La sugerencia fue Zebu pero devio ser Zebra
# 2

# %%
for i in range(len(treinta)):
    bestMatch = CheckBestMatch(csvFile, treinta[i])
    if(bestMatch != csvFile[i]):
        errores_treinta += 1
        print("La palabra ingresada fue:",treinta[i])
        print("La sugerencia fue "+str(bestMatch)+" pero devio ser "+str(csvFile[i]))

print(errores_treinta)
# Out:
# La palabra ingresada fue: Bar
# La sugerencia fue Gar pero devio ser Bear
# La palabra ingresada fue: Dole
# La sugerencia fue Mole pero devio ser Dhole
# La palabra ingresada fue: Dod
# La sugerencia fue Dog pero devio ser Dodo
# La palabra ingresada fue: Magp
# La sugerencia fue Wasp pero devio ser Magpie
# La palabra ingresada fue: Malte
# La sugerencia fue Mule pero devio ser Maltese
# La palabra ingresada fue: Mama
# La sugerencia fue Puma pero devio ser Mammals
# La palabra ingresada fue: Mol
# La sugerencia fue Mole pero devio ser Molly
# La palabra ingresada fue: Sao
# La sugerencia fue Yak pero devio ser Saola
# La palabra ingresada fue: Zebr
# La sugerencia fue Zebu pero devio ser Zebra
# 9

# %%
for i in range(len(cincuenta)):
    bestMatch = CheckBestMatch(csvFile, cincuenta[i])
    if(bestMatch != csvFile[i]):
        errores_cincuenta += 1
        print("La palabra ingresada fue:",cincuenta[i])
        print("La sugerencia fue "+str(bestMatch)+" pero devio ser "+str(csvFile[i]))

print(errores_cincuenta)
# Out:
# La palabra ingresada fue: Affnpice
# La sugerencia fue Magpie pero devio ser Affenpinscher
# La palabra ingresada fue: Afirn Buhs Elep
# La sugerencia fue Fin Whale pero devio ser African Bush Elephant
# La palabra ingresada fue: Afirn Plm Civt
# La sugerencia fue Asian Palm Civet pero devio ser African Palm Civet
# La palabra ingresada fue: Afirn Peng
# La sugerencia fue Ainu Dog pero devio ser African Penguin
# La palabra ingresada fue: Amrcn Bllod
# La sugerencia fue Armadillo pero devio ser American Bulldog
# La palabra ingresada fue: Amrcn Cce Spnai
# La sugerencia fue Marine Toad pero devio ser American Cocker Spaniel
# La palabra ingresada fue: Amrcn Stffosie Trre
# La sugerencia fue Arctic Hare pero devio ser American Staffordshire Terrier
# La palabra ingresada fue: Anvhie
# La sugerencia fue Snake pero devio ser Anchovies
# La palabra ingresada fue: Armail
# La sugerencia fue Snail pero devio ser Armadillo
# La palabra ingresada fue: Aurco
# ...

# %%
for i in range(len(setentaicinco)):
    bestMatch = CheckBestMatch(csvFile, setentaicinco[i])
    if(bestMatch != csvFile[i]):
        errores_setentaicinco += 1
        print("La palabra ingresada fue:",setentaicinco[i])
        print("La sugerencia fue "+str(bestMatch)+" pero devio ser "+str(csvFile[i]))

print(errores_setentaicinco)
# Out:
# La palabra ingresada fue: Ardv
# La sugerencia fue Kudu pero devio ser Aardvark
# La palabra ingresada fue: Abysn
# La sugerencia fue Ibis pero devio ser Abyssinian
# La palabra ingresada fue: Adel Pnu
# La sugerencia fue Aye Aye pero devio ser Adelie Penguin
# La palabra ingresada fue: Affnpic
# La sugerencia fue Tapir pero devio ser Affenpinscher
# La palabra ingresada fue: Afirn Buh Elp
# La sugerencia fue Fin Whale pero devio ser African Bush Elephant
# La palabra ingresada fue: Afirn Cv
# La sugerencia fue Pointer pero devio ser African Civet
# La palabra ingresada fue: Afirn Cwe Fo
# La sugerencia fue Barn Owl pero devio ser African Clawed Frog
# La palabra ingresada fue: Afirn Frs Ele
# La sugerencia fue Fin Whale pero devio ser African Forest Elephant
# La palabra ingresada fue: Afirn Plm Civ
# La sugerencia fue Asian Palm Civet pero devio ser African Palm Civet
# La palabra ingresada fue: Afirn Pen
# La sugerencia fue Reindeer pero devio ser African Penguin
# ...
